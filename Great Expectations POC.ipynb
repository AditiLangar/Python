# %%
# Pip install great expectations library if never used in a particular system before

# !pip install great_expectations
# Out:
# ...
#      ---------------------------------------- 5.4/5.4 MB 1.2 MB/s eta 0:00:00
# ...
#      ------------------------------------ 395.2/395.2 kB 601.5 kB/s eta 0:00:00
# ...
#      -------------------------------------- 813.6/813.6 kB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 109.1/109.1 kB 6.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 49.4/49.4 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.9/1.9 MB 1.4 MB/s eta 0:00:00
# ...
#      ------------------------------------ 345.4/345.4 kB 766.9 kB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   Attempting uninstall: ruamel.yaml
#     Found existing installation: ruamel.yaml 0.17.21
#     Uninstalling ruamel.yaml-0.17.21:
#       Successfully uninstalled ruamel.yaml-0.17.21
# ...

# %% [markdown]
# ### Import all the required libraries

# %%
import pandas as pd
import great_expectations as ge

# %% [markdown]
# ### Read a dataset using GE library

# %%
titanic = ge.read_csv("titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
### other key points:

### 1. The above behaves exactly the same as pandas.read_csv, so you can add parameters to parse your file as below:
### my_df = gx.read_csv(
###    "my_data_directory/my_messy_data.csv",
###    sep="\t",
###    skiprows=3
### )

### 2. You can also use pandas df to read a dataset again using ge as below:
### my_df = ge.from_pandas(my_pandas_df)

### 3. A spark df can also be used to read a dataset using ge:
### from great_expectations.dataset.sparkdf_dataset import SparkDFDataset
### my_df = SparkDFDataset(my_spark_dataframe)

# %% [markdown]
# ### Applying null checks using great expectations library:

# %%
titanic.expect_column_values_to_not_be_null('Name')
# Out:
# {
#   "success": true,
#   "result": {
#     "element_count": 891,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
### Since Name column does not have any NULL values, we see the total percentage as 0

# %%
titanic.expect_column_values_to_not_be_null('Age')
# Out:
# {
#   "success": false,
#   "result": {
#     "element_count": 891,
#     "unexpected_count": 177,
#     "unexpected_percent": 19.865319865319865,
#     "unexpected_percent_total": 19.865319865319865,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# Since Age column has NUll values, we can see the percentage

# %%
### The NULL values can also be verified using pandas as below:

titanic.info()
# Out:
# <class 'great_expectations.dataset.pandas_dataset.PandasDataset'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Total number of rows in the dataset

row_count = len(titanic)

row_count
# Out:
# 891

# %% [markdown]
# ### To check if the values are within a particular range

# %%
titanic.expect_column_values_to_be_between(
    column="Fare",
    min_value=0,
    max_value=20,
)
# Out:
# {
#   "success": false,
#   "result": {
#     "element_count": 891,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 376,
#     "unexpected_percent": 42.19977553310887,
#     "unexpected_percent_total": 42.19977553310887,
#     "unexpected_percent_nonmissing": 42.19977553310887,
#     "partial_unexpected_list": [
#       71.2833,
#       53.1,
#       51.8625,
#       21.075,
#       30.0708,
#       26.55,
#       31.275,
#       29.125,
#       26.0,
#       35.5,
#       21.075,
#       31.3875,
#       263.0,
#       27.7208,
#       146.5208,
#       82.1708,
#       52.0,
#       21.0,
#       41.5792,
#       21.6792
#     ]
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
